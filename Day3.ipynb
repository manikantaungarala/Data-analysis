# %% [markdown]
# PANDAS

# %%
import pandas as pd
import numpy as np
#pd.series(colname,index)
a=np.array([33,44,55,77])
index=[1,2,3,4]
r=pd.Series(a,index)
print(r)
# Out:
# 1    33
# 2    44
# 3    55
# 4    77
# dtype: int64

# %%
import pandas as pd
#pd.series(colname,index)
a=["mani","chandu","shruthi"]
index=[1,2,3]
r=pd.Series(a,index)
print(r)
# Out:
# 1       mani
# 2     chandu
# 3    shruthi
# dtype: object

# %%
dia=pd.read_csv("/diabetcsv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grad=pd.read_csv("/demodt.txt",sep=",")
grad
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxl=pd.read_excel("/diabetes.xlsx")
diaxl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diaxls=pd.read_excel("/diabetes.xlsx",sheet_name="dora")
diaxls
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diaxl.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
dia.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %% [markdown]
# diaxls.describe()

# %%
print(diaxls.shape)
# Out:
# (5, 2)

# %% [markdown]
# print(diaxls.shape[0]) #only rows

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df
print(df.shape)
print(df.isnull())#dfname.isnull() it returns null in the file
# Out:
# (17, 7)
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum()) #column wise returns null values
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df1=df.dropna()#to save the changes,create new data frame or give inplace=true
df1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna(inplace=True)
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# df2.fillna(22.44)

# %%
df2.fillna(33,inplace=True)
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0  33.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K  33.0   9.1   9.9    A+       1
# 9   Rajini        M  33.0   9.1   9.3     A       0
# 10   Kiran        V  33.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0  33.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K  33.0   9.1   9.9    A+       1
# 9   Rajini        M  33.0   9.1   9.3     A       0
# 10   Kiran        V  33.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf = pd.read_csv("/content/grades_withnulls.csv")
mv=mydf['SEM2'].mean()
print(mv)
mydf.fillna(mv,inplace=True)
mydf
# Out:
# 9.0
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#access the data
#iloc=integer location,index
#loc=field name,index
#dfname.loc[index]--->rows
#dfname.loc[st:stop]--->range of rows
#record=row,field=column
mydf.loc[1:3]#range of records
mydf.loc[5]#particular record
# Out:
# Names       Raj
# Initials      M
# SEM1        8.9
# SEM2        9.1
# SEM3        9.3
# Grade         A
# Placed        1
# Name: 5, dtype: object

# %%
mydf.iloc[10:12,0:2]
# Out:
#     Names Initials
# 10  Kiran        V
# 11   Maya        N

# %%
mydf.loc[1:4,"SEM1"]
# Out:
# 1    8.9
# 2    9.9
# 3    7.7
# 4    9.8
# Name: SEM1, dtype: float64

# %%
mydf.iloc[12:14,0:4]#both rows and column for range
# Out:
#      Names Initials  SEM1  SEM2
# 12   Jolin        K   9.8   9.1
# 13  Rajesh        M   8.9   9.1

# %%
mydf[mydf.SEM2>=9]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
mydf[mydf.Names=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#print the records who scores 9.3 in sem3
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
mydf.loc[mydf['SEM2']>=9.2,['Names']]
# Out:
#      Names
# 0      Joe
# 2   Kissan
# 10   Kiran
# 14    Riya
# 15    Sana

# %%
mydf.loc[mydf.SEM1>=9.8,'Names']
# Out:
# 0        Joe
# 2     Kissan
# 4       Jeen
# 6     Hassan
# 12     Jolin
# 15      Sana
# Name: Names, dtype: object

# %%
mydf[mydf.SEM2>=9.0]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
#prints grades of the students who scored more than 9 in sem3
mydf.loc[mydf.SEM3>9.8,'Grade']
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
#to remove duplicates of records
mydf.drop_duplicates()
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.drop_duplicates(inplace=True)
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.head()#bydefault it shows 0 to 4
mydf.head(8)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   9.0     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1

# %%
mydf.tail()#bydefaults it show 0 to 4 total=5
mydf.tail(7)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#accessing using index function
print(mydf[mydf.index==7])
print(mydf.loc[mydf.index==6,'Names'])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# 6    Hassan
# Name: Names, dtype: object

# %%
#columns
mydf.columns #view column names
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#columns
collist=list(mydf.columns) #typecasting into list
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#rename the columns
mydf.rename(columns={"Grade":"GPA"},inplace=True)
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
#creating a new column
#dfname['colname']=values
mydf["Conduct"]='good'
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed Conduct
# 0      Joe        K   9.8  10.0   9.9  A+       1    good
# 1   Rajesh        M   8.9   9.1   9.3   A       1    good
# 2   Kissan        V   9.9   9.8  10.0   A       0    good
# 3     Mary        N   7.7   8.0   9.0   B       0    good
# 4     Jeen        K   9.8   9.1   9.9  A+       1    good
# 5      Raj        M   8.9   9.1   9.3   A       1    good
# 6   Hassan        V   9.9   9.0   9.2   A       1    good
# 7     Mari        N   7.7   8.0   7.1   B       1    good
# 8     Jess        K   9.0   9.1   9.9  A+       1    good
# 9   Rajini        M   9.0   9.1   9.3   A       0    good
# 10   Kiran        V   9.0   9.3   9.2   A       0    good
# 11    Maya        N   7.7   8.0   7.1   B       0    good
# 12   Jolin        K   9.8   9.1   9.9  A+       1    good
# 14    Riya        M   9.3   9.9  10.0   A       1    good
# 15    Sana        V   9.9   9.3   9.2   A       0    good
# ...

# %%
mydf["Average"]=(mydf["SEM1"]+mydf["SEM2"]+mydf["SEM3"])/3
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3     Mary        N   7.7   8.0   9.0     B       0  8.233333
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8     Jess        K   9.0   9.1   9.9    A+       1  9.333333
# 9   Rajini        M   9.0   9.1   9.3     A       0  9.133333
# 10   Kiran        V   9.0   9.3   9.2     A       0  9.166667
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# ...

# %%
import pandas as pd
#data visualization using pandas
mydf['SEM1'].plot.line()#plotting single column
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line() #plotting multiple collumns
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot(kind="scatter",x="Names",y="SEM1")
# Out:
# <Axes: xlabel='Names', ylabel='SEM1'>

# %%
mydf.plot(kind="hist",x="Names",y="SEM2")
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3     Mary        N   7.7   8.0   9.0     B       0  8.233333
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8     Jess        K   9.0   9.1   9.9    A+       1  9.333333
# 9   Rajini        M   9.0   9.1   9.3     A       0  9.133333
# 10   Kiran        V   9.0   9.3   9.2     A       0  9.166667
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# ...

# %%
mydf.to_csv("mydf.csv")#dfname.to_csv("filename.csv")
