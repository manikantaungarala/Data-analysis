# %%
import pandas as pd

# %%
A=pd.read_csv("/content/mydf.CSV")

# %%
import seaborn as sns

# %%
p1= sns.lineplot(x="Names",y="SEM2",data=A)

# %%
sns.relplot(data=A,x="SEM1",y="Names",col="Placed")

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")
dfe
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
#create a relational plot using age as y axis index as x axis seperated by class
#dfe['Index']=range(1,769)
dfe
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
sns.relplot(data=dfe,x="Index",y="age",col="class")

# %%
sns.relplot(data=dfe,x=dfe.Index,y="age",col="class")

# %%
tips=sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="dark")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="size")

# %%
do= sns.load_dataset("dowjones")

# %%
do.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=do, x="Date",y="Price",kind="line")

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %%
sns.catplot(data=tips,x="total_bill",y="day")

# %%
sns.catplot(data=tips,x="total_bill",y="smoker")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,x="time",y="total_bill",kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="box")

# %%
sns.catplot(data=tips,x="time",y="total_bill",kind="box",hue="smoker")

# %%
sns.catplot(data=tips,x="time",y="total_bill",kind="boxen",hue="smoker")

# %%
import seaborn as sns
ccr= sns.load_dataset("car_crashes")
ccr.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.catplot(data=ccr,x="ins_premium",y="alcohol",kind="strip",palette="bright")
# Out:
# <ipython-input-29-591276a1d4a3>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=ccr,x="ins_premium",y="alcohol",kind="strip",palette="bright")

# %%
sns.relplot(data=ccr,x="ins_premium",y="not_distracted",kind="line",hue="total",palette="bright")

# %%
sns.catplot(data=ccr,x="ins_premium",y="alcohol",kind="violin",hue="total",palette="bright")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(data=iris,x="sepal_length",y="petal_width",kind="line",hue="species")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="boxen",hue="species",palette="dark")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="point",hue="species",palette="dark")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="bar",hue="species",palette="dark")

# %%
he=sns.load_dataset("healthexp")
he.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.catplot(data=he,x="Life_Expectancy",y="Year",kind="bar",hue="Country",palette="bright")

# %%
sns.relplot(data=he,x="Life_Expectancy",y="Year",kind="scatter",hue="Country",palette="bright")

# %%
sns.catplot(data=he,x="Life_Expectancy",y="Year",kind="strip",hue="Country",palette="bright")
